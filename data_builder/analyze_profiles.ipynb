# %%
import pandas as pd
import json

# %%
profiles = json.load(open("../data/google_scholar_profiles.json"))
profiles = [{"original_name": p["original_name"], "search_query": p["search_query"], **p["result"]} for p in profiles]

# %%
profiles_df = pd.DataFrame(profiles)
profiles_df.head()
# Out:
#     original_name            search_query             name  \
# 0  Костадин Мишев  Kostadin Mishev, FINKI  Kostadin Mishev
# 1   Петре Ламески    Petre Lameski, FINKI    Petre Lameski
#
#                                                 link  \
# 0  https://scholar.google.com/citations?user=OWsO...
# 1  https://scholar.google.com/citations?user=eidg...
#
#                                         serpapi_link     author_id  \
# 0  https://serpapi.com/search.json?author_id=OWsO...  OWsOOT0AAAAJ
# 1  https://serpapi.com/search.json?author_id=eidg...  eidg6REAAAAJ
#
#                                         affiliations  \
# 0  Assistant Professor, Ss. Cyril and Methodius U...
# 1  Faculty of Computer Sciecne and Engineering, S...
#
#                              email  cited_by
# 0  Verified email at finki.ukim.mk       853
# 1  Verified email at finki.ukim.mk      2837

# %%
profiles_df["email"].unique()
# Out:
#                             name  \
# 0                 Костадин Мишев
# 1                  Петре Ламески
# 2                 Игор Мишковски
# 3                   Дејан Спасов
# 4        Смилка Јанеска Саркањац
# 5                  Ѓорѓи Маџаров
# 6                   Марјан Гушев
# 7                    Иван Чорбев
# 8                 Ристе Стојанов
# 9                   Соња Гиевска
# 10              Бобан Јоксимоски
# 11                Андреа Кулаков
# 12               Весна Димитрова
# 13               Сашо Граматиков
# 14                Бојан Илијоски
# 15            Владимир Трајковиќ
# 16              Георгина Мирчева
# 17               Иван Китановски
# 18                 Анастас Мишев
# 19           Христина Михајлоска
# 20                Панче Рибарски
# 21              Димитар Трајанов
# 22              Андреја Наумоски
# 23             Билјана Стојкоска
# 24               Илинка Иваноска
# 25           Слободан Калајџиски
# 26                Соња Филипоска
# ...
