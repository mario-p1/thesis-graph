# %%
import pandas as pd

from thesis_graph.data import load_thesis_csv
from thesis_graph.utils import load_json_file

# %%
thesis_df = load_thesis_csv("data/committee.csv")

profiles = load_json_file("data/scholar_profiles.json")
profiles_df = pd.DataFrame(profiles, columns=["original_name", "email"])

profiles_df.head()
# Out:
#              original_name                            email
# 0           Костадин Мишев  Verified email at finki.ukim.mk
# 1            Петре Ламески  Verified email at finki.ukim.mk
# 2           Игор Мишковски  Verified email at finki.ukim.mk
# 3             Дејан Спасов  Verified email at finki.ukim.mk
# 4  Смилка Јанеска Саркањац  Verified email at finki.ukim.mk

# %% [markdown]
# Verify that Google Scholar profiles were found for all committee members

# %%
set(profiles_df["original_name"].unique().tolist()) == set(
    thesis_df["mentor"].unique().tolist()
)
# Out:
# True

# %% [markdown]
# Verify that the found Google Scholar profiles correspond to the committee members

# %%
profiles_df["email"].unique()
# Out:
# array(['Verified email at finki.ukim.mk',
#        'Ss. Cyril and Methodius University, Skopje, Faculty of Computer Science and Engineering',
#        'Verified email at tuwien.ac.at', 'Verified email at manu.edu.mk'],
#       dtype=object)

# %%
profiles_df[
    ~profiles_df["email"].isin(
        [
            "Verified email at finki.ukim.mk",
            "Ss. Cyril and Methodius University, Skopje, Faculty of Computer Science and Engineering",
        ]
    )
]
# Out:
#       original_name                           email
# 55  Милош Јовановиќ  Verified email at tuwien.ac.at
# 56  Ласко Баснарков   Verified email at manu.edu.mk
